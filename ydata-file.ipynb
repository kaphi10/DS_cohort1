# %%
import pandas as pd
import numpy as np
# %matplotlib inline
from ydata_profiling import ProfileReport

# %%
df=pd.read_csv('baby_name.csv')
df.head()
# Out:
#    Year of Birth  Gender Ethnicity Child_Name  Count  Rank  count_plus_5
# 0           2011  Female  Hispanic  Geraldine     13    75            18
# 1           2011  Female  Hispanic        Gia     21    67            26
# 2           2011  Female  Hispanic     Gianna     49    42            54
# 3           2011  Female  Hispanic    Giselle     38    51            43
# 4           2011  Female  Hispanic      Grace     36    53            41

# %%
profile=ProfileReport(df, title='BabyName Profiling')
profile.to_notebook_iframe()
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v0.0.dev0&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/ydata-profiling&gt;&lt;meta name=date content=&quot;2024-07-11 13:42:57.252431&quot;&gt;&lt;title&gt;BabyName Profiling&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...
